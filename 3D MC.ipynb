# %%
import aplpy
import astropy
import matplotlib
import matplotlib.pyplot as plt
from astropy import units as u
from astropy.coordinates import SkyCoord
from matplotlib.colors import LogNorm
from astropy.wcs import WCS
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits
import numpy as np

# %%
fig = aplpy.FITSFigure('Xray_Clavel_chandra_pigs-cube.fits',dimensions=[0,1],slices=[1])
fig.show_grayscale()
# Out:
# INFO: Auto-setting vmin to -8.122e-09 [aplpy.core]
# INFO: Auto-setting vmax to  9.015e-08 [aplpy.core]

# %%
astropy.io.fits.info('Xray_Clavel_chandra_pigs-cube.fits')
f = fits.open('Xray_Clavel_chandra_pigs-cube.fits')
w = WCS(f[0].header)
sky = w.pixel_to_world(313, 175, 0)
print(sky)
# Out:
# Filename: Xray_Clavel_chandra_pigs-cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      25   (313, 175, 17)   float64
# [<SkyCoord (Galactic): (l, b) in deg
#     (0.04011111, -0.05227776)>, <Quantity 1999.>]

# %%
CMfig = aplpy.FITSFigure('CMZoom_continuum_pbcor_feathered.fits',convention='wells')
CMfig.show_grayscale(stretch='log',pmin=1, pmax=99,vmin=.001)
#astropy.io.fits.open('CMZoom_continuum_pbcor_feathered.fits',convention='wells')
#CMfig.imshow(image_data, cmap='gray', norm=LogNorm())
# Out:
# INFO: Auto-setting vmax to  6.135e+08 [aplpy.core]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-61029771658a> in <module>
# ----> 1 match_coordinates_sky(matchcoord, catalogcoord)
#
# NameError: name 'match_coordinates_sky' is not defined
